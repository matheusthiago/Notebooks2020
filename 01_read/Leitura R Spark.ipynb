# %% [markdown]
# # Setup

# %%
# install.packages("sparklyr")
# install.packages("dplyr")

# %%
# spark_install()

# %% [markdown]
# # Leitura

# %%
Sys.setenv(JAVA_HOME='/usr/lib/jvm/java-8-openjdk-amd64/jre')

# %%
library(dplyr)
require(sparklyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: sparklyr

# %%
sc <- spark_connect(master = "local")

# %%
setwd("/home/marcus/Documentos/matheus/enertalk-dataset-00/")

# %%
list.dirs()
# Out:
#  [1] "."          "./20161101" "./20161102" "./20161103" "./20161104"
#  [6] "./20161105" "./20161106" "./20161107" "./20161109" "./20161110"
# [11] "./20161111" "./20161112" "./20161113" "./20161114" "./20161115"
# [16] "./20161116" "./20161117" "./20161118" "./20161119" "./20161121"
# [21] "./20161122" "./20161123" "./20161125" "./20161126" "./20161128"
# [26] "./20161129" "./20161130" "./20161201" "./20161202" "./20161203"
# [31] "./20161204" "./20161205" "./20161206" "./20161207" "./20161208"
# [36] "./20161209" "./20161210" "./20161211" "./20161212" "./20161213"
# [41] "./20161214" "./20161215" "./20161216" "./20161217" "./20161218"
# [46] "./20161219" "./20161220" "./20161221" "./20161222" "./20161223"
# [51] "./20161224" "./20161225" "./20161226" "./20161227" "./20161228"
# [56] "./20161229" "./20161230" "./20170101" "./20170102" "./20170103"
# [61] "./20170104" "./20170105" "./20170106" "./20170107" "./20170108"
# [66] "./20170109" "./20170110" "./20170111" "./20170112" "./20170113"
# [71] "./20170114" "./20170115" "./20170116" "./20170117" "./20170118"
# [76] "./20170119" "./20170120" "./20170121" "./20170122" "./20170123"
# [81] "./20170124" "./20170125" "./20170126" "./20170127" "./20170128"
# [86] "./20170129" "./20170130" "./20170131" "./logs"

# %%
tv = spark_read_parquet(sc,path = "00/20161102/01_TV.parquet.gzip")

# %%
show(tv)
# Out:
# # Source: spark<01_TV_parquet_e1075422_d5a9_4e4a_9e2f_c505b347f510> [?? x 4]
#    active_power reactive_power     timestamp `__index_level_0__`
#           <dbl>          <dbl>         <dbl>               <dbl>
#  1         0.28           1.76 1478044800020                   0
#  2         0.19           1.67 1478044800086                   1
#  3         0.08           1.62 1478044800153                   2
#  4         0.14           1.74 1478044800220                   3
#  5         0.14           1.67 1478044800286                   4
#  6         0.22           1.7  1478044800353                   5
#  7         0.18           1.76 1478044800420                   6
#  8         0.28           1.78 1478044800486                   7
#  9         0.15           1.81 1478044800553                   8
# 10         0.22           1.82 1478044800620                   9
# # … with more rows

# %%
spark_disconnect(sc)
